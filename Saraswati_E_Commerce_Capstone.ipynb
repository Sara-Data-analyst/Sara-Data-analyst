# %% [markdown]
# ###  An international e-commerce company based wants to discover key insights from their customer database. The company sells electronic products.

# %% [markdown]
# ### This is the data of product shipment Tracking and The Company want to Know following information:-
# 1. What was Customer Rating ?
# 2. How many the product deliever on time ?
# 3. Is Customer query is being answered if product importance is high, having highest customer rating or being ?

# %% [markdown]
# ###  I started the work on this data through machine larning technique and import numpy and pandas

# %%
# import package
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
# import Data set
data = pd.read_csv("E_Commerce.csv")
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
data = pd.read_csv("E_Commerce.csv")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# properties of the dataframe object
print(data.size)
print(data.shape)
print(len(data))
# Out:
# 131988
# (10999, 12)
# 10999

# %%
# display the top rows
data.head(4)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# ...

# %%
# Dispaly the bottom rows
data.tail(3)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 10996                    0
# 10997                    0
# 10998                    0

# %%
# summary of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
# know about missing values
data.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [markdown]
# ### Accessing the values
# 1. loc() --> use with indexes
# 2. loc()--> use with indexes

# %%
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
data.set_index('Customer_rating', inplace = True)

# %%
data.head()
# Out:
#                  ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Customer_rating
# 2                 1               D           Flight                    4
# 5                 2               F           Flight                    4
# 2                 3               A           Flight                    2
# 3                 4               B           Flight                    3
# 2                 5               C           Flight                    2
#
#                  Cost_of_the_Product  Prior_purchases Product_importance  \
# Customer_rating
# 2                                177                3                low
# 5                                216                2                low
# 2                                183                4                low
# 3                                176                4             medium
# 2                                184                3             medium
#
# ...

# %%
data.loc[5,'Warehouse_block']
# Out:
# Customer_rating
# 5    F
# 5    F
# 5    D
# 5    F
# 5    D
#     ..
# 5    F
# 5    C
# 5    B
# 5    D
# 5    D
# Name: Warehouse_block, Length: 2171, dtype: object

# %%
data.loc[5,'Gender']
# Out:
# Customer_rating
# 5    M
# 5    F
# 5    F
# 5    M
# 5    M
#     ..
# 5    M
# 5    F
# 5    M
# 5    M
# 5    F
# Name: Gender, Length: 2171, dtype: object

# %%
data.iloc[1,1]
# Out:
# 'F'

# %%
data.loc[5,'Product_importance']
# Out:
# 'medium'

# %%
# syntax --> dataframe[lower_row:upper_row, lower_col :upper_col]
data.loc[[1,2],:] # .loc() use with lables
# Out:
#                     ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Customer_rating
# 1                    6               F           Flight                    3
# 1                    8               F           Flight                    4
# 1                   22               B             Ship                    3
# 1                   26               F             Ship                    3
# 1                   27               A             Ship                    4
# ...                ...             ...              ...                  ...
# 2                10977               A           Flight                    3
# 2                10980               F             Ship                    4
# 2                10982               F             Ship                    5
# 2                10992               F             Ship                    5
# 2                10998               F             Ship                    5
#
# ...

# %% [markdown]
# ### .iloc<--use with indexes

# %%
data.head()
# Out:
#                  ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Customer_rating
# 2                 1               D           Flight                    4
# 5                 2               F           Flight                    4
# 2                 3               A           Flight                    2
# 3                 4               B           Flight                    3
# 2                 5               C           Flight                    2
#
#                  Cost_of_the_Product  Prior_purchases Product_importance  \
# Customer_rating
# 2                                177                3                low
# 5                                216                2                low
# 2                                183                4                low
# 3                                176                4             medium
# 2                                184                3             medium
#
# ...

# %%
data.iloc[:4,:] # .iloc() use with indexes
# Out:
#                  ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Customer_rating
# 2                 1               D           Flight                    4
# 5                 2               F           Flight                    4
# 2                 3               A           Flight                    2
# 3                 4               B           Flight                    3
#
#                  Cost_of_the_Product  Prior_purchases Product_importance  \
# Customer_rating
# 2                                177                3                low
# 5                                216                2                low
# 2                                183                4                low
# 3                                176                4             medium
#
#                 Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# Customer_rating
# 2                    F                44           1233                    1
# ...

# %%
data.iloc[:8,:8]
# Out:
#                  ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Customer_rating
# 2                 1               D           Flight                    4
# 5                 2               F           Flight                    4
# 2                 3               A           Flight                    2
# 3                 4               B           Flight                    3
# 2                 5               C           Flight                    2
# 1                 6               F           Flight                    3
# 4                 7               D           Flight                    3
# 1                 8               F           Flight                    4
#
#                  Cost_of_the_Product  Prior_purchases Product_importance  \
# Customer_rating
# 2                                177                3                low
# 5                                216                2                low
# ...

# %%
data.iloc[1,0]
# Out:
# 2

# %%
data.reset_index(inplace=True)

# %% [markdown]
# ## data preprocessing and cleansing

# %%
data = pd.read_csv("E_Commerce.csv")
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %% [markdown]
# ### Find Missing Values

# %%
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# check for missing values
data.isna().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
# first approach is to drop the row with missing values
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
data.isna().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %% [markdown]
# ## duplicate rows

# %%
# check for duplicacy
data.duplicated().sum()
# Out:
# 0

# %%
# knowing the duplicate row
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Warehouse_block, Mode_of_Shipment, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Product_importance, Gender, Discount_offered, Weight_in_gms, Reached.on.Time_Y.N]
# Index: []

# %%
# drop the duplicate row
data.drop_duplicates(keep = 'first', inplace = True)
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# check for duplicacy
data.duplicated().sum()
# Out:
# 0

# %%
# check duplicated row on a subset of columns
data.duplicated(subset=['ID', 'Gender', 'Customer_rating']).sum()
# Out:
# 0

# %%
# save the dataframe
data.to_csv('E_Commerce.csv', index = False)

# %% [markdown]
# ###  Filtering and Manipulation

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# can we find Customer_rating more than 1 of Warehouse_block
# this can be solve with a simple booleon condition
# df['Customer_rating'] >= 5
df[df['Customer_rating'] >=5]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 1          2               F           Flight                    4
# 11        12               F           Flight                    4
# 12        13               D           Flight                    3
# 17        18               F             Ship                    5
# 18        19               D             Ship                    5
# ...      ...             ...              ...                  ...
# 10963  10964               F           Flight                    4
# 10966  10967               C           Flight                    5
# 10971  10972               B           Flight                    5
# 10986  10987               D             Ship                    4
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1                    5                  216                2
# ...

# %%
# can we tell find the customer_rating having more than 5 in Warehouse_block and are female

# %%
df[df['Customer_rating'] >= 5][df['Gender'] =='F']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7868\3914653324.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Customer_rating'] >= 5][df['Gender'] =='F']
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 11        12               F           Flight                    4
# 12        13               D           Flight                    3
# 24        25               D             Ship                    4
# 36        37               D             Ship                    3
# 71        72               F             Ship                    5
# ...      ...             ...              ...                  ...
# 10910  10911               A             Ship                    5
# 10923  10924               B             Ship                    5
# 10928  10929               A             Ship                    3
# 10966  10967               C           Flight                    5
# ...

# %%
df.loc[(df['Customer_rating'] >= 5) & (df['Gender'] =='M'),:]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 1          2               F           Flight                    4
# 17        18               F             Ship                    5
# 18        19               D             Ship                    5
# 19        20               F             Ship                    4
# 22        23               C             Ship                    2
# ...      ...             ...              ...                  ...
# 10911  10912               B             Ship                    4
# 10955  10956               F           Flight                    2
# 10963  10964               F           Flight                    4
# 10971  10972               B           Flight                    5
# 10986  10987               D             Ship                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1                    5                  216                2
# ...

# %%
# know the countof a category in a Categorical variable
# tell me the number of male and female users?
# value_counts()
df['Gender'].value_counts()
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64

# %%
# Highest coustomer Rating
# value_counts()
df['Customer_rating'].value_counts()
# Out:
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: Customer_rating, dtype: int64

# %%
# Find proportion
df['Gender'].value_counts(normalize = True)
# Out:
# F    0.504137
# M    0.495863
# Name: Gender, dtype: float64

# %%
# Find proportion
df['Customer_rating'].value_counts(normalize = True)
# Out:
# 3    0.203564
# 1    0.203200
# 4    0.199018
# 5    0.197382
# 2    0.196836
# Name: Customer_rating, dtype: float64

# %%
# find the number of high rating of 5 
df['Warehouse_block'].value_counts()
# Out:
# F    3666
# D    1834
# A    1833
# B    1833
# C    1833
# Name: Warehouse_block, dtype: int64

# %%
# find the number of Reached.on.Time_Y.N product
df['Reached.on.Time_Y.N'].value_counts()
# Out:
# 1    6563
# 0    4436
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
# extracting a column
df = data['Product_importance']
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head()
# Out:
# 0       low
# 1       low
# 2       low
# 3    medium
# 4    medium
# Name: Product_importance, dtype: object

# %%
df = data[['Product_importance']]
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Product_importance
# 0                low
# 1                low
# 2                low
# 3             medium
# 4             medium

# %%
df['Product_importance'].value_counts()
# Out:
# low       5297
# medium    4754
# high       948
# Name: Product_importance, dtype: int64

# %%
df = pd.read_csv('E_Commerce.csv')
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
df['Gender'].value_counts()
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64

# %%
# import the package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# bar plot
gender_count = [5545,5454]
categories = ['F','M']
plt.bar(categories,gender_count)
plt.xlabel("Gender Categories")
plt.ylabel("Count")
plt.title('Bar Plot')
plt.show()

# %%
# bar plot
Customer_rating = [2239,2235,2189,2171,2165]
categories = [3,1,4,5,2]
plt.bar(categories,Customer_rating)
plt.xlabel("Customer_rating")
plt.ylabel("Count")
plt.title('Bar Plot')
plt.show()

# %%
data['Product_importance'].value_counts()
# Out:
# low       5297
# medium    4754
# high       948
# Name: Product_importance, dtype: int64

# %%
# count plot
sns.countplot(x = data['Product_importance'])
plt.show()

# %%
# count plot
sns.countplot(x = data['Customer_rating'])
plt.show()

# %%
# count plot
sns.countplot(x = data['Customer_rating'])
plt.show()

# %% [markdown]
# ### E_commerce Prediction

# %%
# import common library packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# import data set
E_Commerce_df = pd.read_csv('E_Commerce.csv')
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
E_Commerce_df.shape
# Out:
# (10999, 12)

# %%
E_Commerce_df['Customer_rating'].value_counts(normalize=True)
# Out:
# 3    0.203564
# 1    0.203200
# 4    0.199018
# 5    0.197382
# 2    0.196836
# Name: Customer_rating, dtype: float64

# %%
E_Commerce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
# perfomr correlation analysis among variables
corr_values = E_Commerce_df.corr()
print(corr_values)
# Out:
#                            ID  Customer_care_calls  Customer_rating  \
# ID                   1.000000             0.188998        -0.005722
# Customer_care_calls  0.188998             1.000000         0.012209
# Customer_rating     -0.005722             0.012209         1.000000
# Cost_of_the_Product  0.196791             0.323182         0.009270
# Prior_purchases      0.145369             0.180771         0.013179
# Discount_offered    -0.598278            -0.130750        -0.003124
# Weight_in_gms        0.278312            -0.276615        -0.001897
# Reached.on.Time_Y.N -0.411822            -0.067126         0.013119
#
#                      Cost_of_the_Product  Prior_purchases  Discount_offered  \
# ID                              0.196791         0.145369         -0.598278
# Customer_care_calls             0.323182         0.180771         -0.130750
# Customer_rating                 0.009270         0.013179         -0.003124
# ...

# %%
# plotting figsize=tmap for correlattion analysis
plt.figure(figsize = (10, 8))
sns.heatmap(corr_values, annot = True)
# Out:
# <Axes: >

# %%
# import data set
E_Commerce_df = pd.read_csv('E_Commerce.csv')
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# input variables ---> Cost_of_the_Product
# output variable --> Customer_rating
# Model an eq.
# simple Linear regression
# Customer_rating = w0 + w1(Customer_rating) + w2(Cost_of_the_Product)
# simple Linear regression
# Customer_ratings = w0 + w1(Cost_of_the_Product)+w2( Customer_rating)
data_simple = data[['Cost_of_the_Product','Customer_rating']].copy()
data_simple.head()
# Out:
#    Cost_of_the_Product  Customer_rating
# 0                  177                2
# 1                  216                5
# 2                  183                2
# 3                  176                3
# 4                  184                2

# %%
# help to understand the quality and relationship of data
#plotting a distribution for input
sns.distplot(data_simple['Cost_of_the_Product'])
plt.show()

# %%
#plotting a distribution for output
sns.distplot(data_simple['Customer_rating'])
plt.show()

# %%
#Bivariate analysis
sns.scatterplot(x = data_simple['Cost_of_the_Product'],y =
data_simple['Customer_rating'])
plt.show()

# %%
data_simple.corr()
# Out:
#                      Cost_of_the_Product  Customer_rating
# Cost_of_the_Product              1.00000          0.00927
# Customer_rating                  0.00927          1.00000

# %%
data_simple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cost_of_the_Product  10999 non-null  int64
#  1   Customer_rating      10999 non-null  int64
# dtypes: int64(2)
# memory usage: 172.0 KB

# %%
#separating input and output
X = data_simple[['Cost_of_the_Product']]
y = data_simple['Customer_rating']

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train ,X_test, y_train, y_test = train_test_split(X, y, test_size =
0.2, random_state = 10)
print(X_train.shape, X_test.shape)
# Out:
# (8799, 1) (2200, 1)

# %%
# Fit a model
from sklearn.linear_model import LinearRegression
simple_linear = LinearRegression()
simple_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Customer_ratings = w0 + w1(Cost_of_the_Product)
print(simple_linear.intercept_, simple_linear.coef_)
# Out:
# 2.8878664519535038 [0.00056813]

# %%
y_pred = simple_linear.predict(X_test)
y_pred
# Out:
# array([3.0367173 , 3.04126237, 2.98615347, ..., 3.02933158, 2.94524789,
#        3.03387664])

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("R-2 Score : " ,r2_score(y_test,y_pred))
print("Root Mean Square Error : " ,
mean_squared_error(y_test,y_pred)**0.5)
# Out:
# R-2 Score :  -0.005057531754139699
# Root Mean Square Error :  1.4242180083881044

# %%
#plotting the regression line
plt.scatter(X,y , c = 'yellow')
plt.plot(X_test, y_pred)
plt.show()

# %%
X_train.values.mean()
# Out:
# 210.37458802136607

# %%
y_train.mean()
# Out:
# 3.0073872030912603

# %%
# ybar = w0 + w1* xbar
2.8878664519535038 + 0.00056813* 210.37458802136607
# Out:
# 3.0073865666460824

# %% [markdown]
# ##  Multiple Linear Regression

# %%
# multiple linear regression equation
# sales = w0 + w1(Customer_care_calls) + w2(Customer_rating) +w3(Cost_of_the_Product)+(Prior_purchases)
data_multiple = data.copy()
data_multiple.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %% [markdown]
# ###  Univariate Analysis

# %%
plt.figure(figsize= (15,10))
plt.subplot(3, 2, 1)
plt.title("E_Commerce")
sns.distplot(data_multiple['Customer_care_calls'])
plt.subplot(3, 2, 2)
plt.title("E_Commerce")
sns.boxplot(x = data_multiple['Customer_care_calls'])
plt.subplot(3, 2, 3)
plt.title("Radio Advertisement")
sns.distplot(data_multiple['Customer_rating'])
plt.subplot(3,2, 4)
plt.title("Radio Advertisement")
sns.boxplot(x = data_multiple['Customer_rating'])
plt.subplot(3, 2, 5)
plt.title("NewsPaper Advertisement")
sns.distplot(data_multiple['Cost_of_the_Product'])
plt.subplot(3,2, 6)
plt.title("NewsPaper Advertisement")
sns.boxplot(x = data_multiple['Cost_of_the_Product'])
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.pairplot(data_multiple)
plt.show()

# %%
sns.heatmap(data_multiple.corr(),annot= True)
plt.show()

# %%
# Seaprating input and output
X = data_multiple.drop(['Customer_rating'],axis =1)
y = data_multiple['Customer_rating']

# %%
#spliting the data int on train and test
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test =
train_test_split(X,y,test_size=0.25,random_state=10)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (8799, 1) (2200, 1)

# %%
data = pd.read_csv("E_Commerce.csv")
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# Train and Test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (8799, 1) (2200, 1)

# %%
# scalar
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
X_train[:5]
# Out:
# array([[ 1.13630668],
#        [-1.0894855 ],
#        [ 0.28343304],
#        [ 1.09470309],
#        [-0.77745856]])

# %% [markdown]
# ## Model Building

# %%
from sklearn.svm import SVC

svc_clf = SVC(C = 10.0)

svc_clf.fit(X_train, y_train)
# Out:
# SVC(C=10.0)

# %%
# validate the model
from sklearn.metrics import accuracy_score, classification_report
print("Accuracy with train data : ", accuracy_score(y_train, svc_clf.predict(X_train)))
print("Accuracy with test data : ", accuracy_score(y_test, svc_clf.predict(X_test)))
# Out:
# Accuracy with train data :  0.21479713603818615
# Accuracy with test data :  0.195

# %% [markdown]
# ## Conclusion
# ###  1.What was Customer Rating ?
# Ans. Got the highest rating is 3.
#
# ### 2.How many the product deliever on time ?
# Ans.The product deliever on time is 4436.
#
# ### 3.Is Customer query is being answered if product importance is high, having highest customer rating or being ?
# Ans. No , High rating medium product received.

# %% [markdown]
# ####   Hence Data Science is an important tool for every business in today’s world. It helps us become smarter, faster, and better at what we do — if only because it can provide answers to complex questions we may have never known how to ask. Moreover, the ability to process big data has become more and more accessible thanks to the emergence of technology such as artificial intelligence (AI), machine learning, and ML Dataops.
#    #### Data scientists use statistical methods such as regression analysis and machine learning algorithms to extract useful information from large sets of data (structured, unstructured, and semi-structured) to find patterns and discover new insights.
#
#    #### The benefits of data science go beyond just providing better insights into your customers’ needs. It also helps you change how you do business due to this data.

# %% [markdown]
# ## Thank You
